# %% [markdown]
# # 03 TF-IDF Features`n`nBuild and inspect TF-IDF feature representations.`n`n## Goals`n- Vectorize cleaned reviews`n- Compare vocabulary settings`n- Export reusable artifacts if needed`n
