# %% [markdown]
# # 06 Deep Model`n`nTrain and evaluate a deep learning model.`n`n## Goals`n- Prepare sequence or embedding inputs`n- Train the selected deep architecture`n- Compare against the baseline`n
